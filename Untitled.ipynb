# %%
import json
from twython import TwythonStreamer

tweets = []

CONSUMER_KEY = 'l7IxLkkUlePaCUKrK4r66q2yT'
CONSUMER_SECRET = 'ymdrkdkAwA6qQtjzwlZGgVczlSr4eTyngfTOVSOD855lPN1hwM'
ACCESS_TOKEN = '803229586268024832-mFWj255hS0MOrmWxXMRe2J5cbVA5kmB'
ACCESS_TOKEN_SECRET ='vOnVU6vmGI4fk5CqBrivCjgChgfEY0IWLgQHmDPw0Iztg'

class MyStreamer (TwythonStreamer):

    def on_success(self, data):
        if data['lang'] == 'en':
            tweets.append(data)
            print 'received tweet no', len(tweets)

        if len(tweets) >= 30:
            self.disconnect()
    def on_error(self, status_code, data):
        self.disconnect()


stream =MyStreamer(CONSUMER_KEY, CONSUMER_SECRET, ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
stream.statuses.filter(track=['breez london', 'cloud london','cold london', 'ice london', \
                       'icy london', 'icey london', 'drizzle london', 'frost london',\
                       'wind london', 'mild london', 'dew london', 'freez london',\
                       'downpour london', 'shower london', 'rain london', 'frost london',\
                       'nippy london', 'hail london', 'temp london', 'gail london', 'gust london',\
                       'sleet london', 'heat london', 'storm london', 'slush london',\
                       'smog london', 'fog london', 'flood london', 'weather london', \
                       'visibility london', 'warm london', 'mist london','chill london',\
                       'thunder london', 'lightning london', 'snow london', 'hot london',\
                       'sun london', 'boiling london', 'baltic london', 'burn london']) #this is your silter/search term you are looking for tweets about...

with open(r"C:\\Users\\Student24\\Documents\\twitter\\twiiter_python\\twitter_weather.json","w") as tw:    #r+ to append file, "w" to over write
    json.dump(tweets,tw)
# Out:
# received tweet no 1
# received tweet no 2
# received tweet no 3
# received tweet no 4
# received tweet no 5
# received tweet no 6
# received tweet no 7
# received tweet no 8
# received tweet no 9
# received tweet no 10
# received tweet no 11
# received tweet no 12
# received tweet no 13
# received tweet no 14
# received tweet no 15
# received tweet no 16
# received tweet no 17
# received tweet no 18
# received tweet no 19
# received tweet no 20
# received tweet no 21
# received tweet no 22
# received tweet no 23
# received tweet no 24
# received tweet no 25
# received tweet no 26
# received tweet no 27
# received tweet no 28
# received tweet no 29
# received tweet no 30

# %%
import json

with open (r"C:\\Users\\Student24\\Documents\\twitter\\twiiter_python\\twitter_weather.json","r") as j:
    data = json.load(j) #.load, converts to dict

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(data)

# %%
from datetime import datetime
import time

dffinal=df[['text']]
dffinal['Date']=(pd.to_datetime(df['created_at'])).dt.date


dffinal
# Out:
# C:\Users\Student24\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                                  text        Date
# 0   RT @CleanAirLondon: UK blanketed in smog exact...  2016-12-07
# 1   #London Dec 07 10:50 Temperature 12C few cloud...  2016-12-07
# 2   Ice skating rink at the National History Museu...  2016-12-07
# 3   @siLPH_Co Google says its 12 degrees in London...  2016-12-07
# 4   6am: Mostly Cloudy -0.5C - Feels: -5C - Wind: ...  2016-12-07
# 5   #japanese bondage porn hot emo chicks having s...  2016-12-07
# 6   Is the winter cold stealing the beauty of your...  2016-12-07
# 7   RT @thehistoryguy: This week in 1952 London wa...  2016-12-07
# ...
